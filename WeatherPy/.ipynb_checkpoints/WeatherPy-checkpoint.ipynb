# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import scipy.stats as sts
from datetime import date
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
weather_response = requests.get(query_url)
weather_json = weather_response.json()
# print(json.dumps(weather_json, indent = 4))

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city_count = 0

city_dict = {}
city_list = []

city_name_list = []
city_lat_list = []
city_lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []
country_list = []
date_list = []



print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    city_count += 1
    
    if city_count <= 9:
        
        try:
            print(f'Processing Record Number 0{city_count} | {city}')
            query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()

            city_name_list.append(weather_json['name'])
            city_lat_list.append(weather_json['coord']['lat'])
            city_lng_list.append(weather_json['coord']['lon'])
            max_temp_list.append(weather_json['main']['temp_max'])
            humidity_list.append(weather_json['main']['humidity'])
            cloudiness_list.append(weather_json['clouds']['all'])
            wind_speed_list.append(weather_json['wind']['speed'])
            country_list.append(weather_json['sys']['country'])
            date_list.append(weather_json['dt'])

        except:
            print("City not found. Skipping...")
        
    else:
        try:
            print(f'Processing Record Number {city_count} | {city}')
            query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()

            city_name_list.append(weather_json['name'])
            city_lat_list.append(weather_json['coord']['lat'])
            city_lng_list.append(weather_json['coord']['lon'])
            max_temp_list.append(weather_json['main']['temp_max'])
            humidity_list.append(weather_json['main']['humidity'])
            cloudiness_list.append(weather_json['clouds']['all'])
            wind_speed_list.append(weather_json['wind']['speed'])
            country_list.append(weather_json['sys']['country'])
            date_list.append(weather_json['dt'])

        except:
            print("City not found. Skipping...")
        
city_dict = {'City_Name': city_name_list,
                'Lat': city_lat_list, 
                'Lon': city_lng_list, 
                'Max_Temp': max_temp_list, 
                'Humidity': humidity_list,
                'Clouds': cloudiness_list,
                'Wind_Speed': wind_speed_list,
                'Country': country_list,
                'Date': date_list}
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record Number 01 | zlatoustovsk
# City not found. Skipping...
# Processing Record Number 02 | atuona
# Processing Record Number 03 | mataura
# Processing Record Number 04 | sao miguel do araguaia
# Processing Record Number 05 | seoul
# Processing Record Number 06 | nikolskoye
# Processing Record Number 07 | rungata
# City not found. Skipping...
# Processing Record Number 08 | namibe
# Processing Record Number 09 | pevek
# Processing Record Number 10 | butaritari
# Processing Record Number 11 | ushuaia
# Processing Record Number 12 | puerto ayora
# Processing Record Number 13 | yellowknife
# Processing Record Number 14 | jacareacanga
# Processing Record Number 15 | gat
# Processing Record Number 16 | khudumelapye
# Processing Record Number 17 | hay river
# Processing Record Number 18 | castro
# Processing Record Number 19 | orasac
# Processing Record Number 20 | caluquembe
# Processing Record Number 21 | kaputa
# Processing Record Number 22 | taolanaro
# City not found. Skipping...
# Processing Record Number 23 | vuktyl
# Processing Record Number 24 | bredasdorp
# Processing Record Number 25 | jamestown
# Processing Record Number 26 | port alfred
# Processing Record Number 27 | rikitea
# Processing Record Number 28 | ribeira grande
# Processing Record Number 29 | kulhudhuffushi
# Processing Record Number 30 | hilo
# Processing Record Number 31 | lebu
# Processing Record Number 32 | busselton
# Processing Record Number 33 | one hundred mile house
# City not found. Skipping...
# Processing Record Number 34 | sumen
# City not found. Skipping...
# Processing Record Number 35 | belushya guba
# City not found. Skipping...
# Processing Record Number 36 | carnarvon
# Processing Record Number 37 | ambilobe
# Processing Record Number 38 | albany
# Processing Record Number 39 | punta arenas
# Processing Record Number 40 | mahebourg
# Processing Record Number 41 | grindavik
# Processing Record Number 42 | golubitskaya
# Processing Record Number 43 | richards bay
# Processing Record Number 44 | longyearbyen
# Processing Record Number 45 | barrow
# Processing Record Number 46 | saint-philippe
# Processing Record Number 47 | evensk
# Processing Record Number 48 | juneau
# Processing Record Number 49 | polis
# Processing Record Number 50 | maghama
# City not found. Skipping...
# Processing Record Number 51 | makinsk
# Processing Record Number 52 | vaini
# Processing Record Number 53 | zemio
# Processing Record Number 54 | wangqing
# Processing Record Number 55 | cherskiy
# Processing Record Number 56 | kapaa
# Processing Record Number 57 | belaya gora
# Processing Record Number 58 | chuy
# Processing Record Number 59 | amderma
# City not found. Skipping...
# Processing Record Number 60 | khatanga
# Processing Record Number 61 | hermanus
# Processing Record Number 62 | sentyabrskiy
# City not found. Skipping...
# Processing Record Number 63 | khani
# Processing Record Number 64 | henties bay
# Processing Record Number 65 | bonavista
# Processing Record Number 66 | saint george
# Processing Record Number 67 | lewiston
# Processing Record Number 68 | florianopolis
# Processing Record Number 69 | coxim
# Processing Record Number 70 | ilulissat
# Processing Record Number 71 | bluff
# Processing Record Number 72 | salmas
# Processing Record Number 73 | illoqqortoormiut
# City not found. Skipping...
# Processing Record Number 74 | touros
# Processing Record Number 75 | manono
# Processing Record Number 76 | dikson
# Processing Record Number 77 | baillif
# Processing Record Number 78 | constitucion
# Processing Record Number 79 | peniche
# Processing Record Number 80 | monchegorsk
# Processing Record Number 81 | saskylakh
# Processing Record Number 82 | nizhneyansk
# City not found. Skipping...
# Processing Record Number 83 | victoria point
# Processing Record Number 84 | roald
# Processing Record Number 85 | hobart
# Processing Record Number 86 | chara
# Processing Record Number 87 | georgetown
# Processing Record Number 88 | bramsche
# Processing Record Number 89 | changtu
# Processing Record Number 90 | umzimvubu
# City not found. Skipping...
# Processing Record Number 91 | port macquarie
# Processing Record Number 92 | grand river south east
# City not found. Skipping...
# Processing Record Number 93 | bengkulu
# Processing Record Number 94 | pisco
# Processing Record Number 95 | massaguet
# Processing Record Number 96 | ostrovnoy
# Processing Record Number 97 | thompson
# Processing Record Number 98 | arraial do cabo
# Processing Record Number 99 | cabo san lucas
# Processing Record Number 100 | paita
# Processing Record Number 101 | lensk
# Processing Record Number 102 | srednekolymsk
# Processing Record Number 103 | waitara
# Processing Record Number 104 | makakilo city
# Processing Record Number 105 | qasigiannguit
# Processing Record Number 106 | kulunda
# Processing Record Number 107 | saint-pierre
# Processing Record Number 108 | nuuk
# Processing Record Number 109 | abu jubayhah
# City not found. Skipping...
# Processing Record Number 110 | tual
# Processing Record Number 111 | iqaluit
# Processing Record Number 112 | avarua
# Processing Record Number 113 | asse
# Processing Record Number 114 | glotovka
# Processing Record Number 115 | leningradskiy
# Processing Record Number 116 | ploemeur
# Processing Record Number 117 | airai
# Processing Record Number 118 | armacao dos buzios
# City not found. Skipping...
# Processing Record Number 119 | souillac
# Processing Record Number 120 | clyde river
# Processing Record Number 121 | yelatma
# Processing Record Number 122 | miyako
# Processing Record Number 123 | gurgan
# City not found. Skipping...
# Processing Record Number 124 | amboasary
# Processing Record Number 125 | severo-kurilsk
# Processing Record Number 126 | hemnes
# City not found. Skipping...
# Processing Record Number 127 | altamira
# Processing Record Number 128 | caravelas
# Processing Record Number 129 | tsihombe
# City not found. Skipping...
# Processing Record Number 130 | upernavik
# Processing Record Number 131 | chokurdakh
# Processing Record Number 132 | lorengau
# Processing Record Number 133 | guaraniacu
# Processing Record Number 134 | east london
# Processing Record Number 135 | fukue
# Processing Record Number 136 | awjilah
# Processing Record Number 137 | westerland
# Processing Record Number 138 | nagar karnul
# Processing Record Number 139 | tuktoyaktuk
# Processing Record Number 140 | ambon
# Processing Record Number 141 | houma
# Processing Record Number 142 | suao
# City not found. Skipping...
# Processing Record Number 143 | camacha
# Processing Record Number 144 | nador
# Processing Record Number 145 | moorhead
# Processing Record Number 146 | nanortalik
# Processing Record Number 147 | sinnamary
# Processing Record Number 148 | cap malheureux
# Processing Record Number 149 | batagay-alyta
# Processing Record Number 150 | bambous virieux
# Processing Record Number 151 | bababe
# City not found. Skipping...
# Processing Record Number 152 | new norfolk
# Processing Record Number 153 | taga dzong
# City not found. Skipping...
# Processing Record Number 154 | bethel
# Processing Record Number 155 | labuhan
# Processing Record Number 156 | ponta do sol
# Processing Record Number 157 | saldanha
# Processing Record Number 158 | sitka
# Processing Record Number 159 | hambantota
# Processing Record Number 160 | vaitupu
# City not found. Skipping...
# Processing Record Number 161 | kaupanger
# Processing Record Number 162 | hithadhoo
# Processing Record Number 163 | sfantu gheorghe
# Processing Record Number 164 | yulara
# Processing Record Number 165 | rehnan
# Processing Record Number 166 | mar del plata
# Processing Record Number 167 | pangody
# Processing Record Number 168 | impfondo
# Processing Record Number 169 | codrington
# Processing Record Number 170 | the valley
# Processing Record Number 171 | vangaindrano
# Processing Record Number 172 | lata
# Processing Record Number 173 | calama
# Processing Record Number 174 | karoi
# Processing Record Number 175 | cape town
# Processing Record Number 176 | provideniya
# Processing Record Number 177 | villa union
# Processing Record Number 178 | bowen
# Processing Record Number 179 | san cristobal
# Processing Record Number 180 | buchanan
# Processing Record Number 181 | port elizabeth
# Processing Record Number 182 | mogadishu
# Processing Record Number 183 | barentsburg
# City not found. Skipping...
# Processing Record Number 184 | turayf
# Processing Record Number 185 | sarkand
# Processing Record Number 186 | lubao
# Processing Record Number 187 | klaksvik
# Processing Record Number 188 | nisia floresta
# Processing Record Number 189 | two hills
# Processing Record Number 190 | port hardy
# Processing Record Number 191 | kodiak
# Processing Record Number 192 | sistranda
# Processing Record Number 193 | talnakh
# Processing Record Number 194 | trelew
# Processing Record Number 195 | debre zeyit
# Processing Record Number 196 | mys shmidta
# City not found. Skipping...
# Processing Record Number 197 | banda aceh
# Processing Record Number 198 | pangnirtung
# Processing Record Number 199 | altay
# Processing Record Number 200 | sohag
# Processing Record Number 201 | cheuskiny
# City not found. Skipping...
# Processing Record Number 202 | berlevag
# Processing Record Number 203 | waingapu
# Processing Record Number 204 | broome
# Processing Record Number 205 | qaanaaq
# Processing Record Number 206 | mkushi
# Processing Record Number 207 | porto novo
# Processing Record Number 208 | fortuna
# Processing Record Number 209 | garden city
# Processing Record Number 210 | kavieng
# Processing Record Number 211 | tasiilaq
# Processing Record Number 212 | margate
# Processing Record Number 213 | grand centre
# City not found. Skipping...
# Processing Record Number 214 | victoria
# Processing Record Number 215 | najran
# Processing Record Number 216 | te anau
# Processing Record Number 217 | raudeberg
# Processing Record Number 218 | saint-gratien
# Processing Record Number 219 | shubarkuduk
# Processing Record Number 220 | baruun-urt
# Processing Record Number 221 | ahipara
# Processing Record Number 222 | aviles
# Processing Record Number 223 | matamoros
# Processing Record Number 224 | nioro
# Processing Record Number 225 | misratah
# Processing Record Number 226 | qaqortoq
# Processing Record Number 227 | kabare
# Processing Record Number 228 | itarema
# Processing Record Number 229 | akdepe
# Processing Record Number 230 | kamenskoye
# City not found. Skipping...
# Processing Record Number 231 | baft
# Processing Record Number 232 | torbay
# Processing Record Number 233 | chipinge
# Processing Record Number 234 | kaitangata
# Processing Record Number 235 | chauk
# Processing Record Number 236 | vostok
# Processing Record Number 237 | lathrop
# Processing Record Number 238 | kawalu
# Processing Record Number 239 | geraldton
# Processing Record Number 240 | isla vista
# Processing Record Number 241 | kachiry
# Processing Record Number 242 | esperance
# Processing Record Number 243 | atar
# Processing Record Number 244 | avera
# Processing Record Number 245 | agas
# Processing Record Number 246 | lagoa
# Processing Record Number 247 | lavrentiya
# Processing Record Number 248 | chicama
# Processing Record Number 249 | rantepao
# Processing Record Number 250 | taltal
# Processing Record Number 251 | balimo
# City not found. Skipping...
# Processing Record Number 252 | tura
# Processing Record Number 253 | doka
# Processing Record Number 254 | kruisfontein
# Processing Record Number 255 | kurgan
# Processing Record Number 256 | shingu
# Processing Record Number 257 | port-gentil
# Processing Record Number 258 | jubayl
# City not found. Skipping...
# Processing Record Number 259 | alice springs
# Processing Record Number 260 | sorvag
# City not found. Skipping...
# Processing Record Number 261 | attawapiskat
# City not found. Skipping...
# Processing Record Number 262 | guerrero negro
# Processing Record Number 263 | praia
# Processing Record Number 264 | mumford
# Processing Record Number 265 | katsuura
# Processing Record Number 266 | kijang
# Processing Record Number 267 | batemans bay
# Processing Record Number 268 | baghdad
# Processing Record Number 269 | vila velha
# Processing Record Number 270 | oeiras
# Processing Record Number 271 | djambala
# Processing Record Number 272 | bambanglipuro
# Processing Record Number 273 | yomitan
# City not found. Skipping...
# Processing Record Number 274 | puerto baquerizo moreno
# Processing Record Number 275 | sioux lookout
# Processing Record Number 276 | sanandaj
# Processing Record Number 277 | bitung
# Processing Record Number 278 | hamilton
# Processing Record Number 279 | dongsheng
# Processing Record Number 280 | zarubino
# Processing Record Number 281 | marawi
# Processing Record Number 282 | east saint louis
# Processing Record Number 283 | cochrane
# Processing Record Number 284 | karratha
# Processing Record Number 285 | paradwip
# City not found. Skipping...
# Processing Record Number 286 | armizonskoye
# Processing Record Number 287 | pakokku
# Processing Record Number 288 | amapa
# Processing Record Number 289 | ancud
# Processing Record Number 290 | egvekinot
# Processing Record Number 291 | rawson
# Processing Record Number 292 | saint-leu
# Processing Record Number 293 | la palma
# Processing Record Number 294 | port pirie
# Processing Record Number 295 | emerald
# Processing Record Number 296 | sibolga
# Processing Record Number 297 | fort saint john
# City not found. Skipping...
# Processing Record Number 298 | maldonado
# Processing Record Number 299 | paraiso
# Processing Record Number 300 | tocopilla
# Processing Record Number 301 | ranong
# Processing Record Number 302 | moindou
# Processing Record Number 303 | naftah
# City not found. Skipping...
# Processing Record Number 304 | moroni
# Processing Record Number 305 | cairns
# Processing Record Number 306 | cockburn town
# Processing Record Number 307 | kushmurun
# Processing Record Number 308 | norman wells
# Processing Record Number 309 | lasa
# Processing Record Number 310 | anori
# Processing Record Number 311 | portland
# Processing Record Number 312 | lompoc
# Processing Record Number 313 | olinda
# Processing Record Number 314 | wanaka
# Processing Record Number 315 | los llanos de aridane
# Processing Record Number 316 | tuatapere
# Processing Record Number 317 | laguna
# Processing Record Number 318 | gamba
# Processing Record Number 319 | palabuhanratu
# City not found. Skipping...
# Processing Record Number 320 | luderitz
# Processing Record Number 321 | bolshegrivskoye
# City not found. Skipping...
# Processing Record Number 322 | wampusirpi
# City not found. Skipping...
# Processing Record Number 323 | boa vista
# Processing Record Number 324 | ust-charyshskaya pristan
# Processing Record Number 325 | okahandja
# Processing Record Number 326 | barsbuttel
# City not found. Skipping...
# Processing Record Number 327 | wattegama
# Processing Record Number 328 | aklavik
# Processing Record Number 329 | loa janan
# Processing Record Number 330 | januaria
# Processing Record Number 331 | panzhihua
# Processing Record Number 332 | harper
# Processing Record Number 333 | caconda
# Processing Record Number 334 | havre-saint-pierre
# Processing Record Number 335 | broken hill
# Processing Record Number 336 | maibong
# Processing Record Number 337 | port blair
# Processing Record Number 338 | little current
# Processing Record Number 339 | kahului
# Processing Record Number 340 | luwuk
# Processing Record Number 341 | port hedland
# Processing Record Number 342 | khvoynaya
# Processing Record Number 343 | montecristo
# Processing Record Number 344 | patan
# Processing Record Number 345 | takaka
# Processing Record Number 346 | labuan
# Processing Record Number 347 | naze
# Processing Record Number 348 | lazaro cardenas
# Processing Record Number 349 | celestun
# Processing Record Number 350 | karamea
# City not found. Skipping...
# Processing Record Number 351 | samusu
# City not found. Skipping...
# Processing Record Number 352 | san patricio
# Processing Record Number 353 | linhares
# Processing Record Number 354 | diamantino
# Processing Record Number 355 | thanh hoa
# Processing Record Number 356 | laurel
# Processing Record Number 357 | kaduqli
# Processing Record Number 358 | grong
# Processing Record Number 359 | utiroa
# City not found. Skipping...
# Processing Record Number 360 | bhanjanagar
# Processing Record Number 361 | half moon bay
# Processing Record Number 362 | knysna
# Processing Record Number 363 | gigmoto
# Processing Record Number 364 | zambezi
# Processing Record Number 365 | college
# Processing Record Number 366 | cozumel
# Processing Record Number 367 | shirokiy
# Processing Record Number 368 | honiara
# Processing Record Number 369 | aykhal
# Processing Record Number 370 | leshukonskoye
# Processing Record Number 371 | rudbar
# Processing Record Number 372 | jishou
# Processing Record Number 373 | kankan
# Processing Record Number 374 | hvide sande
# Processing Record Number 375 | lac du bonnet
# Processing Record Number 376 | leinefelde
# Processing Record Number 377 | opuwo
# Processing Record Number 378 | barraute
# Processing Record Number 379 | amzya
# Processing Record Number 380 | santa maria
# Processing Record Number 381 | mitsamiouli
# Processing Record Number 382 | beloha
# Processing Record Number 383 | tazovskiy
# Processing Record Number 384 | moron
# Processing Record Number 385 | yermakovskoye
# Processing Record Number 386 | carman
# Processing Record Number 387 | tezu
# Processing Record Number 388 | ternate
# Processing Record Number 389 | villaviciosa
# Processing Record Number 390 | rocky mountain house
# Processing Record Number 391 | san sebastian coatan
# Processing Record Number 392 | bilma
# Processing Record Number 393 | aktau
# Processing Record Number 394 | korla
# Processing Record Number 395 | cotonou
# Processing Record Number 396 | komsomolskiy
# Processing Record Number 397 | dolbeau
# City not found. Skipping...
# Processing Record Number 398 | saint pete beach
# Processing Record Number 399 | pita
# Processing Record Number 400 | dunedin
# Processing Record Number 401 | suntar
# Processing Record Number 402 | mount gambier
# Processing Record Number 403 | casambalangan
# Processing Record Number 404 | saint-francois
# Processing Record Number 405 | oistins
# Processing Record Number 406 | babanusah
# City not found. Skipping...
# Processing Record Number 407 | tiksi
# Processing Record Number 408 | dingle
# Processing Record Number 409 | zabaykalsk
# Processing Record Number 410 | alofi
# Processing Record Number 411 | paamiut
# Processing Record Number 412 | louisbourg
# City not found. Skipping...
# Processing Record Number 413 | buqayq
# City not found. Skipping...
# Processing Record Number 414 | tumannyy
# City not found. Skipping...
# Processing Record Number 415 | athmallik
# Processing Record Number 416 | kem
# Processing Record Number 417 | ascension
# Processing Record Number 418 | thinadhoo
# Processing Record Number 419 | ostersund
# Processing Record Number 420 | umm lajj
# Processing Record Number 421 | aleksandro-nevskiy
# Processing Record Number 422 | kawakawa
# Processing Record Number 423 | tiznit
# Processing Record Number 424 | port moresby
# Processing Record Number 425 | kodinsk
# Processing Record Number 426 | sibut
# Processing Record Number 427 | muisne
# Processing Record Number 428 | madimba
# Processing Record Number 429 | arrecife
# Processing Record Number 430 | vanavara
# Processing Record Number 431 | mlonggo
# Processing Record Number 432 | jacksonville
# Processing Record Number 433 | huanren
# Processing Record Number 434 | kalianget
# Processing Record Number 435 | flinders
# Processing Record Number 436 | dali
# Processing Record Number 437 | dinsor
# City not found. Skipping...
# Processing Record Number 438 | saint-augustin
# Processing Record Number 439 | ibra
# Processing Record Number 440 | escalerillas
# Processing Record Number 441 | tidore
# City not found. Skipping...
# Processing Record Number 442 | mitu
# Processing Record Number 443 | iskateley
# Processing Record Number 444 | vardo
# Processing Record Number 445 | port lincoln
# Processing Record Number 446 | kassala
# Processing Record Number 447 | bairiki
# Processing Record Number 448 | mancio lima
# Processing Record Number 449 | weiser
# Processing Record Number 450 | trincomalee
# Processing Record Number 451 | jiroft
# City not found. Skipping...
# Processing Record Number 452 | marsabit
# Processing Record Number 453 | naron
# Processing Record Number 454 | beringovskiy
# Processing Record Number 455 | huarmey
# Processing Record Number 456 | polunochnoye
# Processing Record Number 457 | raver
# Processing Record Number 458 | bubaque
# Processing Record Number 459 | khonsar
# City not found. Skipping...
# Processing Record Number 460 | sao filipe
# Processing Record Number 461 | roebourne
# Processing Record Number 462 | sao felix do xingu
# Processing Record Number 463 | severo-yeniseyskiy
# Processing Record Number 464 | tshikapa
# Processing Record Number 465 | kudahuvadhoo
# Processing Record Number 466 | nelson bay
# Processing Record Number 467 | pedasi
# Processing Record Number 468 | general pico
# Processing Record Number 469 | bud
# Processing Record Number 470 | marsh harbour
# Processing Record Number 471 | nouadhibou
# Processing Record Number 472 | bonthe
# Processing Record Number 473 | homer
# Processing Record Number 474 | fernley
# Processing Record Number 475 | antofagasta
# Processing Record Number 476 | riyadh
# Processing Record Number 477 | padang
# Processing Record Number 478 | nassogne
# Processing Record Number 479 | kapoeta
# Processing Record Number 480 | huadian
# Processing Record Number 481 | qandahar
# City not found. Skipping...
# Processing Record Number 482 | kununurra
# Processing Record Number 483 | vao
# Processing Record Number 484 | paredon
# Processing Record Number 485 | faanui
# Processing Record Number 486 | khilok
# Processing Record Number 487 | walvis bay
# Processing Record Number 488 | mormugao
# Processing Record Number 489 | saleaula
# City not found. Skipping...
# Processing Record Number 490 | mildura
# Processing Record Number 491 | sorland
# Processing Record Number 492 | arman
# Processing Record Number 493 | balabac
# Processing Record Number 494 | carbonia
# Processing Record Number 495 | kuching
# Processing Record Number 496 | kavaratti
# Processing Record Number 497 | meyungs
# City not found. Skipping...
# Processing Record Number 498 | roma
# Processing Record Number 499 | tanete
# Processing Record Number 500 | sangar
# Processing Record Number 501 | ugoofaaru
# Processing Record Number 502 | maromitsa
# Processing Record Number 503 | nanga eboko
# Processing Record Number 504 | boyolangu
# Processing Record Number 505 | sola
# Processing Record Number 506 | dakar
# Processing Record Number 507 | tazmalt
# Processing Record Number 508 | dvinskoy
# Processing Record Number 509 | nguiu
# City not found. Skipping...
# Processing Record Number 510 | valdivia
# Processing Record Number 511 | el cobre
# Processing Record Number 512 | kloulklubed
# Processing Record Number 513 | whitehorse
# Processing Record Number 514 | neiafu
# Processing Record Number 515 | monteiro
# Processing Record Number 516 | barsi
# Processing Record Number 517 | soyo
# Processing Record Number 518 | malwan
# City not found. Skipping...
# Processing Record Number 519 | hadgaon
# Processing Record Number 520 | akhnur
# Processing Record Number 521 | boende
# Processing Record Number 522 | saint anthony
# Processing Record Number 523 | soldato-aleksandrovskoye
# Processing Record Number 524 | buala
# Processing Record Number 525 | bolungarvik
# City not found. Skipping...
# Processing Record Number 526 | oranjemund
# Processing Record Number 527 | marzuq
# Processing Record Number 528 | vanimo
# Processing Record Number 529 | bandiagara
# Processing Record Number 530 | soubre
# Processing Record Number 531 | prince rupert
# Processing Record Number 532 | flin flon
# Processing Record Number 533 | dire dawa
# Processing Record Number 534 | harstad
# Processing Record Number 535 | olafsvik
# Processing Record Number 536 | arlit
# Processing Record Number 537 | san rafael del sur
# Processing Record Number 538 | aasiaat
# Processing Record Number 539 | coquimbo
# Processing Record Number 540 | saint-ambroise
# Processing Record Number 541 | salym
# Processing Record Number 542 | eureka
# Processing Record Number 543 | pacific grove
# Processing Record Number 544 | sao francisco
# Processing Record Number 545 | krapivinskiy
# Processing Record Number 546 | cayenne
# Processing Record Number 547 | shreveport
# Processing Record Number 548 | havelock
# Processing Record Number 549 | sao joao da barra
# Processing Record Number 550 | westport
# Processing Record Number 551 | hasaki
# Processing Record Number 552 | trofors
# Processing Record Number 553 | hofn
# Processing Record Number 554 | lagunas
# Processing Record Number 555 | labrea
# Processing Record Number 556 | ustyuzhna
# Processing Record Number 557 | lere
# Processing Record Number 558 | goderich
# Processing Record Number 559 | abha
# Processing Record Number 560 | atlantic city
# Processing Record Number 561 | takoradi
# Processing Record Number 562 | balgazyn
# Processing Record Number 563 | santiago del estero
# Processing Record Number 564 | omsukchan
# Processing Record Number 565 | svetlaya
# Processing Record Number 566 | kamaishi
# Processing Record Number 567 | monrovia
# Processing Record Number 568 | batagay
# Processing Record Number 569 | shache
# Processing Record Number 570 | igarka
# Processing Record Number 571 | martapura
# Processing Record Number 572 | moultonborough
# Processing Record Number 573 | isangel
# Processing Record Number 574 | teluknaga
# Processing Record Number 575 | pavlovsk
# Processing Record Number 576 | kuytun
# Processing Record Number 577 | mounana
# Processing Record Number 578 | madang
# Processing Record Number 579 | toyooka
# Processing Record Number 580 | yerbogachen
# Processing Record Number 581 | veraval
# Processing Record Number 582 | kargopol
# Processing Record Number 583 | serdobsk
# Processing Record Number 584 | tarudant
# City not found. Skipping...
# Processing Record Number 585 | xining
# Processing Record Number 586 | bukachacha
# Processing Record Number 587 | ketchikan
# Processing Record Number 588 | xinqing

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(city_dict)

# %%
city_df.set_index('City_Name')
# Out:
#                           Lat     Lon  Max_Temp  Humidity  Clouds  Wind_Speed  \
# City_Name
# Atuona                  -9.80 -139.03     78.82        75      69       18.59
# Mataura                -46.19  168.86     51.58        57      68        5.88
# São Miguel do Araguaia -13.28  -50.16     79.90        16      36        5.01
# Seoul                   37.57  126.98     80.60       100      90        6.40
# Nikolskoye              59.70   30.79     54.00        93      90        4.47
# ...                       ...     ...       ...       ...     ...         ...
# Serdobsk                52.46   44.22     66.18        58      99        5.50
# Xining                  36.62  101.77     55.89        59      30        3.31
# Bukachacha              52.98  116.92     54.34        60      50        9.89
# Ketchikan               55.34 -131.65     60.80        77      75        6.93
# Xinqing                 48.23  129.50     61.59        95     100       10.96
#
#                        Country        Date
# City_Name
# Atuona                      PF  1598571448
# Mataura                     NZ  1598571803
# São Miguel do Araguaia      BR  1598571803
# Seoul                       KR  1598571417
# Nikolskoye                  RU  1598571461
# ...                        ...         ...
# Serdobsk                    RU  1598571886
# Xining                      CN  1598571887
# Bukachacha                  RU  1598571887
# Ketchikan                   US  1598571887
# Xinqing                     CN  1598571887
#
# [530 rows x 8 columns]

# %%
city_df.to_csv('city_data.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# checks to see if there are any cities in the list with more than 100% humidity.

extra_humid = 0

for h in city_df['Humidity']:
    if h > 100:
        extra_humid =+ 1
        
if extra_humid > 0:
    print("You need to do this step!")

else:
    print("You can skip this step!")
# Out:
# You can skip this step!

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
current_date = date.today()

# %%
lat_plot = city_df['Lat']
temp_plot = city_df['Max_Temp']

plt.scatter(lat_plot, temp_plot, edgecolor="k")
plt.title(f'City Latitude vs Maximum Temperature ({current_date})')
plt.ylabel('Max Temp (F)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig('Lat_vs_Temp.png')

# Analyzing how maximum temperature is affected by the change in latitude

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
humidity_plot = city_df['Humidity']

plt.scatter(lat_plot, humidity_plot, edgecolor="k")
plt.title(f'City Latitude vs Humidity ({current_date})')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig('Lat_vs_Humidity.png')

# Analyzing how humidity is affected by the change in latitude

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clouds_plot = city_df['Clouds']

plt.scatter(lat_plot, clouds_plot, edgecolor="k")
plt.title(f'City Latitude vs Cloudiness ({current_date})')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig('Lat_vs_Clouds.png')

# Analyzing how cloudiness is affected by the change in latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
windSpeed_plot = city_df['Wind_Speed']

plt.scatter(lat_plot, clouds_plot, edgecolor="k")
plt.title(f'City Latitude vs Wind Speed ({current_date})')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig('Lat_vs_WindSpeed.png')

# Analyzing how cloudiness is affected by the change in latitude

# %% [markdown]
# ## Linear Regression

# %%
#Isolating the northern latitudes
lat_north = city_df.loc[city_df['Lat']>=0]
north_df = pd.DataFrame(lat_north)

# %%
#isolating the southern latitudes
lat_south = city_df.loc[city_df['Lat']<0]
south_df = pd.DataFrame(lat_south)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Max_Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.grid(b = True, alpha = .25)
plt.title(f'Northern Hemisphere - Max Temp vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)} indicating a strong negative correlation.')
# Out:
# The linear regression line equation is: y = -0.52x + 87.92.
# The correlation is: -0.77 indicating a strong negative correlation.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Max_Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Max Temp vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)} indicating a strong positive correlation.')
# Out:
# The linear regression line equation is: y = 0.69x + 80.3.
# The correlation is: 0.8 indicating a strong positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = -0.07x + 76.71.
# The correlation is: -0.08, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.08x + 72.1.
# The correlation is: 0.06, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Clouds']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which indicates there is no coorelation.')
# Out:
# The linear regression line equation is: y = -0.11x + 62.9.
# The correlation is: -0.07, which indicates there is no coorelation.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Clouds']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.31x + 44.16.
# The correlation is: 0.12, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Wind_Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.01x + 6.95.
# The correlation is: 0.03, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Wind_Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = -0.09x + 5.94.
# The correlation is: -0.22, which does not indicate a very strong coorelation.
