# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import scipy.stats as sts
from datetime import date
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
weather_response = requests.get(query_url)
weather_json = weather_response.json()
# print(json.dumps(weather_json, indent = 4))

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city_count = 0

city_dict = {}
city_list = []

city_name_list = []
city_lat_list = []
city_lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []
country_list = []
date_list = []



print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    city_count += 1
    
    if city_count <= 9:
        
        try:
            print(f'Processing Record Number 0{city_count} | {city}')
            query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()

            city_name_list.append(weather_json['name'])
            city_lat_list.append(weather_json['coord']['lat'])
            city_lng_list.append(weather_json['coord']['lon'])
            max_temp_list.append(weather_json['main']['temp_max'])
            humidity_list.append(weather_json['main']['humidity'])
            cloudiness_list.append(weather_json['clouds']['all'])
            wind_speed_list.append(weather_json['wind']['speed'])
            country_list.append(weather_json['sys']['country'])
            date_list.append(weather_json['dt'])

        except:
            print("City not found. Skipping...")
        
    else:
        try:
            print(f'Processing Record Number {city_count} | {city}')
            query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()

            city_name_list.append(weather_json['name'])
            city_lat_list.append(weather_json['coord']['lat'])
            city_lng_list.append(weather_json['coord']['lon'])
            max_temp_list.append(weather_json['main']['temp_max'])
            humidity_list.append(weather_json['main']['humidity'])
            cloudiness_list.append(weather_json['clouds']['all'])
            wind_speed_list.append(weather_json['wind']['speed'])
            country_list.append(weather_json['sys']['country'])
            date_list.append(weather_json['dt'])

        except:
            print("City not found. Skipping...")
        
city_dict = {'City_Name': city_name_list,
                'Lat': city_lat_list, 
                'Lon': city_lng_list, 
                'Max_Temp': max_temp_list, 
                'Humidity': humidity_list,
                'Clouds': cloudiness_list,
                'Wind_Speed': wind_speed_list,
                'Country': country_list,
                'Date': date_list}
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record Number 01 | butaritari
# Processing Record Number 02 | albany
# Processing Record Number 03 | dikson
# Processing Record Number 04 | taoudenni
# Processing Record Number 05 | castro
# Processing Record Number 06 | longyearbyen
# Processing Record Number 07 | lagoa
# Processing Record Number 08 | port alfred
# Processing Record Number 09 | hermanus
# Processing Record Number 10 | lolua
# City not found. Skipping...
# Processing Record Number 11 | hilo
# Processing Record Number 12 | villa rica
# Processing Record Number 13 | belushya guba
# City not found. Skipping...
# Processing Record Number 14 | sola
# Processing Record Number 15 | charters towers
# Processing Record Number 16 | zhigansk
# Processing Record Number 17 | punta arenas
# Processing Record Number 18 | vestmanna
# Processing Record Number 19 | barrow
# Processing Record Number 20 | ancud
# Processing Record Number 21 | upata
# Processing Record Number 22 | yellowknife
# Processing Record Number 23 | nemuro
# Processing Record Number 24 | ushuaia
# Processing Record Number 25 | phan thiet
# Processing Record Number 26 | mookane
# Processing Record Number 27 | hanmer springs
# Processing Record Number 28 | faanui
# Processing Record Number 29 | busselton
# Processing Record Number 30 | mataura
# Processing Record Number 31 | malpe
# Processing Record Number 32 | clyde river
# Processing Record Number 33 | sahrak
# City not found. Skipping...
# Processing Record Number 34 | elliot lake
# Processing Record Number 35 | salalah
# Processing Record Number 36 | gaoual
# Processing Record Number 37 | nantucket
# Processing Record Number 38 | aflu
# City not found. Skipping...
# Processing Record Number 39 | arraial do cabo
# Processing Record Number 40 | henties bay
# Processing Record Number 41 | vaini
# Processing Record Number 42 | edd
# Processing Record Number 43 | tual
# Processing Record Number 44 | lebu
# Processing Record Number 45 | orsha
# Processing Record Number 46 | karratha
# Processing Record Number 47 | taolanaro
# City not found. Skipping...
# Processing Record Number 48 | aripuana
# Processing Record Number 49 | rochegda
# Processing Record Number 50 | kiunga
# Processing Record Number 51 | kaitangata
# Processing Record Number 52 | los llanos de aridane
# Processing Record Number 53 | rikitea
# Processing Record Number 54 | bozdar
# Processing Record Number 55 | port elizabeth
# Processing Record Number 56 | qaanaaq
# Processing Record Number 57 | west wendover
# Processing Record Number 58 | entebbe
# Processing Record Number 59 | jamestown
# Processing Record Number 60 | camacha
# Processing Record Number 61 | constantine
# Processing Record Number 62 | oktyabrskiy
# Processing Record Number 63 | coquimbo
# Processing Record Number 64 | alamos
# Processing Record Number 65 | victoria
# Processing Record Number 66 | nadym
# Processing Record Number 67 | hofn
# Processing Record Number 68 | catalao
# Processing Record Number 69 | vestmannaeyjar
# Processing Record Number 70 | bathsheba
# Processing Record Number 71 | chokurdakh
# Processing Record Number 72 | bengkulu
# Processing Record Number 73 | norman wells
# Processing Record Number 74 | sentyabrskiy
# City not found. Skipping...
# Processing Record Number 75 | bredasdorp
# Processing Record Number 76 | urdzhar
# City not found. Skipping...
# Processing Record Number 77 | melita
# Processing Record Number 78 | sitka
# Processing Record Number 79 | new norfolk
# Processing Record Number 80 | kruisfontein
# Processing Record Number 81 | bethel
# Processing Record Number 82 | ilulissat
# Processing Record Number 83 | severo-kurilsk
# Processing Record Number 84 | sabha
# Processing Record Number 85 | bluff
# Processing Record Number 86 | laguna
# Processing Record Number 87 | meulaboh
# Processing Record Number 88 | cabo san lucas
# Processing Record Number 89 | matara
# Processing Record Number 90 | kahului
# Processing Record Number 91 | sretensk
# Processing Record Number 92 | pacific grove
# Processing Record Number 93 | okhansk
# Processing Record Number 94 | svetlogorsk
# Processing Record Number 95 | port lincoln
# Processing Record Number 96 | codrington
# Processing Record Number 97 | sao filipe
# Processing Record Number 98 | birnin kebbi
# Processing Record Number 99 | tiarei
# Processing Record Number 100 | porto-vecchio
# Processing Record Number 101 | shingu
# Processing Record Number 102 | thompson
# Processing Record Number 103 | diamantino
# Processing Record Number 104 | tura
# Processing Record Number 105 | riedlingen
# Processing Record Number 106 | maneadero
# Processing Record Number 107 | cape town
# Processing Record Number 108 | navabad
# City not found. Skipping...
# Processing Record Number 109 | samarai
# Processing Record Number 110 | nguiu
# City not found. Skipping...
# Processing Record Number 111 | kamenskoye
# City not found. Skipping...
# Processing Record Number 112 | illoqqortoormiut
# City not found. Skipping...
# Processing Record Number 113 | tuktoyaktuk
# Processing Record Number 114 | srednekolymsk
# Processing Record Number 115 | camana
# Processing Record Number 116 | mar del plata
# Processing Record Number 117 | east london
# Processing Record Number 118 | saskylakh
# Processing Record Number 119 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record Number 120 | khash
# Processing Record Number 121 | zhangye
# Processing Record Number 122 | mizdah
# Processing Record Number 123 | post falls
# Processing Record Number 124 | sharan
# Processing Record Number 125 | nouadhibou
# Processing Record Number 126 | vostok
# Processing Record Number 127 | wasilla
# Processing Record Number 128 | ulvik
# Processing Record Number 129 | puerto escondido
# Processing Record Number 130 | belyy yar
# Processing Record Number 131 | zainsk
# Processing Record Number 132 | vyazniki
# Processing Record Number 133 | bouake
# Processing Record Number 134 | comodoro rivadavia
# Processing Record Number 135 | avarua
# Processing Record Number 136 | gobabis
# Processing Record Number 137 | hami
# Processing Record Number 138 | tasiilaq
# Processing Record Number 139 | bahir dar
# Processing Record Number 140 | wagar
# Processing Record Number 141 | reque
# Processing Record Number 142 | mahebourg
# Processing Record Number 143 | cacu
# Processing Record Number 144 | anamur
# Processing Record Number 145 | willowmore
# Processing Record Number 146 | rio gallegos
# Processing Record Number 147 | hobart
# Processing Record Number 148 | scottsbluff
# Processing Record Number 149 | praia da vitoria
# Processing Record Number 150 | ksenyevka
# City not found. Skipping...
# Processing Record Number 151 | ribeira grande
# Processing Record Number 152 | port hardy
# Processing Record Number 153 | san cristobal
# Processing Record Number 154 | lompoc
# Processing Record Number 155 | barentsburg
# City not found. Skipping...
# Processing Record Number 156 | lagos
# Processing Record Number 157 | owando
# Processing Record Number 158 | atar
# Processing Record Number 159 | lampa
# Processing Record Number 160 | zaporizhzhya
# Processing Record Number 161 | chumikan
# Processing Record Number 162 | geraldton
# Processing Record Number 163 | bambous virieux
# Processing Record Number 164 | namatanai
# Processing Record Number 165 | souillac
# Processing Record Number 166 | vaitupu
# City not found. Skipping...
# Processing Record Number 167 | hambantota
# Processing Record Number 168 | harlingen
# Processing Record Number 169 | pokosnoye
# Processing Record Number 170 | nikolskoye
# Processing Record Number 171 | kazanskaya
# Processing Record Number 172 | bagn
# Processing Record Number 173 | kelo
# Processing Record Number 174 | yeppoon
# Processing Record Number 175 | kapaa
# Processing Record Number 176 | adrar
# Processing Record Number 177 | saint-philippe
# Processing Record Number 178 | labuhan
# Processing Record Number 179 | gillette
# Processing Record Number 180 | puerto ayora
# Processing Record Number 181 | winnemucca
# Processing Record Number 182 | kaputa
# Processing Record Number 183 | lorengau
# Processing Record Number 184 | karabulak
# Processing Record Number 185 | castanos
# Processing Record Number 186 | kodiak
# Processing Record Number 187 | pevek
# Processing Record Number 188 | komsomolskiy
# Processing Record Number 189 | milkovo
# Processing Record Number 190 | preobrazheniye
# Processing Record Number 191 | linxia
# Processing Record Number 192 | horta
# Processing Record Number 193 | aketi
# Processing Record Number 194 | ojinaga
# Processing Record Number 195 | grand river south east
# City not found. Skipping...
# Processing Record Number 196 | otradnoye
# Processing Record Number 197 | carnarvon
# Processing Record Number 198 | rock sound
# Processing Record Number 199 | isangel
# Processing Record Number 200 | dalvik
# Processing Record Number 201 | alofi
# Processing Record Number 202 | qaqortoq
# Processing Record Number 203 | sistranda
# Processing Record Number 204 | tigzirt
# Processing Record Number 205 | banswada
# Processing Record Number 206 | galchino
# City not found. Skipping...
# Processing Record Number 207 | muroto
# Processing Record Number 208 | mahanoro
# Processing Record Number 209 | ilhabela
# Processing Record Number 210 | ahipara
# Processing Record Number 211 | sungaipenuh
# Processing Record Number 212 | okhotsk
# Processing Record Number 213 | mys shmidta
# City not found. Skipping...
# Processing Record Number 214 | guerrero negro
# Processing Record Number 215 | pala
# Processing Record Number 216 | natal
# Processing Record Number 217 | camiri
# Processing Record Number 218 | xiamen
# Processing Record Number 219 | raymond
# Processing Record Number 220 | den helder
# Processing Record Number 221 | nizhneyansk
# City not found. Skipping...
# Processing Record Number 222 | luanda
# Processing Record Number 223 | ulaanbaatar
# Processing Record Number 224 | zolotinka
# City not found. Skipping...
# Processing Record Number 225 | aquiraz
# Processing Record Number 226 | esperance
# Processing Record Number 227 | aloleng
# Processing Record Number 228 | leh
# Processing Record Number 229 | asau
# Processing Record Number 230 | roma
# Processing Record Number 231 | atuona
# Processing Record Number 232 | padang
# Processing Record Number 233 | asfi
# Processing Record Number 234 | udachnyy
# Processing Record Number 235 | chakulia
# Processing Record Number 236 | namibe
# Processing Record Number 237 | ust-ishim
# Processing Record Number 238 | jogindarnagar
# Processing Record Number 239 | hualmay
# Processing Record Number 240 | zehdenick
# Processing Record Number 241 | garchitorena
# Processing Record Number 242 | luderitz
# Processing Record Number 243 | ebeltoft
# Processing Record Number 244 | broome
# Processing Record Number 245 | aras
# Processing Record Number 246 | cayenne
# Processing Record Number 247 | hasaki
# Processing Record Number 248 | rani
# Processing Record Number 249 | muscat
# Processing Record Number 250 | santa maria
# Processing Record Number 251 | terra santa
# Processing Record Number 252 | khatanga
# Processing Record Number 253 | upernavik
# Processing Record Number 254 | ketchikan
# Processing Record Number 255 | gigmoto
# Processing Record Number 256 | nome
# Processing Record Number 257 | puerto pinasco
# City not found. Skipping...
# Processing Record Number 258 | kindu
# Processing Record Number 259 | tokur
# Processing Record Number 260 | veraval
# Processing Record Number 261 | cherskiy
# Processing Record Number 262 | roald
# Processing Record Number 263 | anadyr
# Processing Record Number 264 | tiksi
# Processing Record Number 265 | terme
# Processing Record Number 266 | teotitlan
# Processing Record Number 267 | necochea
# Processing Record Number 268 | port moresby
# Processing Record Number 269 | mangrol
# Processing Record Number 270 | grand gaube
# Processing Record Number 271 | turka
# Processing Record Number 272 | ati
# Processing Record Number 273 | klyuchi
# Processing Record Number 274 | sarankhola
# Processing Record Number 275 | lisala
# Processing Record Number 276 | bilibino
# Processing Record Number 277 | hobyo
# Processing Record Number 278 | igarka
# Processing Record Number 279 | gizycko
# Processing Record Number 280 | antofagasta
# Processing Record Number 281 | yulara
# Processing Record Number 282 | pahrump
# Processing Record Number 283 | pangai
# Processing Record Number 284 | qovlar
# Processing Record Number 285 | shelburne
# Processing Record Number 286 | kaeo
# Processing Record Number 287 | jibuti
# Processing Record Number 288 | areosa
# Processing Record Number 289 | vila velha
# Processing Record Number 290 | bowen
# Processing Record Number 291 | marcona
# City not found. Skipping...
# Processing Record Number 292 | ulagan
# Processing Record Number 293 | mao
# Processing Record Number 294 | saint george
# Processing Record Number 295 | prince rupert
# Processing Record Number 296 | luorong
# Processing Record Number 297 | japura
# Processing Record Number 298 | asilah
# Processing Record Number 299 | north platte
# Processing Record Number 300 | nara
# Processing Record Number 301 | ixtapa
# Processing Record Number 302 | pisco
# Processing Record Number 303 | jumla
# Processing Record Number 304 | touros
# Processing Record Number 305 | puteyets
# Processing Record Number 306 | lingao
# Processing Record Number 307 | cabo rojo
# Processing Record Number 308 | north bend
# Processing Record Number 309 | malmesbury
# Processing Record Number 310 | fortuna
# Processing Record Number 311 | urumqi
# Processing Record Number 312 | burica
# City not found. Skipping...
# Processing Record Number 313 | saldanha
# Processing Record Number 314 | kuznechnoye
# Processing Record Number 315 | lebork
# Processing Record Number 316 | homer
# Processing Record Number 317 | tautira
# Processing Record Number 318 | bacolod
# Processing Record Number 319 | sherbrooke
# Processing Record Number 320 | georgetown
# Processing Record Number 321 | flin flon
# Processing Record Number 322 | constitucion
# Processing Record Number 323 | palana
# Processing Record Number 324 | naze
# Processing Record Number 325 | ijaki
# City not found. Skipping...
# Processing Record Number 326 | champerico
# Processing Record Number 327 | petatlan
# Processing Record Number 328 | klerksdorp
# Processing Record Number 329 | kuche
# City not found. Skipping...
# Processing Record Number 330 | lingyuan
# Processing Record Number 331 | batemans bay
# Processing Record Number 332 | fairbanks
# Processing Record Number 333 | sungairaya
# Processing Record Number 334 | havre-saint-pierre
# Processing Record Number 335 | evensk
# Processing Record Number 336 | kolda
# Processing Record Number 337 | vila franca do campo
# Processing Record Number 338 | novopavlovka
# Processing Record Number 339 | houma
# Processing Record Number 340 | mildura
# Processing Record Number 341 | mazabuka
# Processing Record Number 342 | saran
# Processing Record Number 343 | roswell
# Processing Record Number 344 | terbuny
# Processing Record Number 345 | ascension
# Processing Record Number 346 | villa oliva
# City not found. Skipping...
# Processing Record Number 347 | lata
# Processing Record Number 348 | tala
# Processing Record Number 349 | selu
# Processing Record Number 350 | katsuura
# Processing Record Number 351 | gamovo
# Processing Record Number 352 | warqla
# City not found. Skipping...
# Processing Record Number 353 | marzuq
# Processing Record Number 354 | ust-kuyga
# Processing Record Number 355 | mehamn
# Processing Record Number 356 | dingle
# Processing Record Number 357 | denpasar
# Processing Record Number 358 | torbay
# Processing Record Number 359 | murray bridge
# Processing Record Number 360 | buenos aires
# Processing Record Number 361 | chernyshevskiy
# Processing Record Number 362 | port hedland
# Processing Record Number 363 | bundibugyo
# Processing Record Number 364 | nanortalik
# Processing Record Number 365 | kem
# Processing Record Number 366 | kayes
# Processing Record Number 367 | bentiu
# Processing Record Number 368 | half moon bay
# Processing Record Number 369 | batkovici
# City not found. Skipping...
# Processing Record Number 370 | lalmohan
# Processing Record Number 371 | gondanglegi
# Processing Record Number 372 | kisangani
# Processing Record Number 373 | agadez
# Processing Record Number 374 | leningradskiy
# Processing Record Number 375 | vryburg
# Processing Record Number 376 | coahuayana
# Processing Record Number 377 | beringovskiy
# Processing Record Number 378 | taitung
# Processing Record Number 379 | sosua
# Processing Record Number 380 | inhambane
# Processing Record Number 381 | cidreira
# Processing Record Number 382 | pemba
# Processing Record Number 383 | siloam springs
# Processing Record Number 384 | basco
# Processing Record Number 385 | provideniya
# Processing Record Number 386 | vila do maio
# Processing Record Number 387 | bungu
# Processing Record Number 388 | miranda
# Processing Record Number 389 | zhuanghe
# Processing Record Number 390 | moerai
# Processing Record Number 391 | omboue
# Processing Record Number 392 | kirakira
# Processing Record Number 393 | husavik
# Processing Record Number 394 | bitlis
# Processing Record Number 395 | kupang
# Processing Record Number 396 | beloha
# Processing Record Number 397 | novikovo
# Processing Record Number 398 | verkhoyansk
# Processing Record Number 399 | keetmanshoop
# Processing Record Number 400 | hithadhoo
# Processing Record Number 401 | monte cristi
# City not found. Skipping...
# Processing Record Number 402 | rapid valley
# Processing Record Number 403 | progreso
# Processing Record Number 404 | ponta do sol
# Processing Record Number 405 | ericeira
# Processing Record Number 406 | rajsamand
# Processing Record Number 407 | sindor
# Processing Record Number 408 | kismayo
# Processing Record Number 409 | lethem
# Processing Record Number 410 | ruatoria
# City not found. Skipping...
# Processing Record Number 411 | andevoranto
# City not found. Skipping...
# Processing Record Number 412 | heihe
# Processing Record Number 413 | jalu
# Processing Record Number 414 | luena
# Processing Record Number 415 | deh rawud
# City not found. Skipping...
# Processing Record Number 416 | koungou
# Processing Record Number 417 | togur
# Processing Record Number 418 | kavaratti
# Processing Record Number 419 | chuy
# Processing Record Number 420 | lavumisa
# Processing Record Number 421 | moissala
# Processing Record Number 422 | baruun-urt
# Processing Record Number 423 | kalaleh
# Processing Record Number 424 | tigwi
# City not found. Skipping...
# Processing Record Number 425 | bokspits
# City not found. Skipping...
# Processing Record Number 426 | airai
# Processing Record Number 427 | arti
# Processing Record Number 428 | ayan
# Processing Record Number 429 | minas novas
# Processing Record Number 430 | monchegorsk
# Processing Record Number 431 | huarmey
# Processing Record Number 432 | tumannyy
# City not found. Skipping...
# Processing Record Number 433 | ola
# Processing Record Number 434 | san patricio
# Processing Record Number 435 | srandakan
# Processing Record Number 436 | miri
# Processing Record Number 437 | yar-sale
# Processing Record Number 438 | gazanjyk
# Processing Record Number 439 | nago
# Processing Record Number 440 | attawapiskat
# City not found. Skipping...
# Processing Record Number 441 | dudinka
# Processing Record Number 442 | christchurch
# Processing Record Number 443 | hella
# Processing Record Number 444 | tambacounda
# Processing Record Number 445 | zlobin
# Processing Record Number 446 | saint-joseph
# Processing Record Number 447 | manzhouli
# Processing Record Number 448 | tairua
# Processing Record Number 449 | mayumba
# Processing Record Number 450 | ledyard
# Processing Record Number 451 | deputatskiy
# Processing Record Number 452 | coromandel
# Processing Record Number 453 | kysyl-syr
# Processing Record Number 454 | messias
# Processing Record Number 455 | emerald
# Processing Record Number 456 | charlestown
# Processing Record Number 457 | sandnessjoen
# Processing Record Number 458 | kodinsk
# Processing Record Number 459 | severo-yeniseyskiy
# Processing Record Number 460 | tsihombe
# City not found. Skipping...
# Processing Record Number 461 | lexington
# Processing Record Number 462 | sabang
# Processing Record Number 463 | makakilo city
# Processing Record Number 464 | kathu
# Processing Record Number 465 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record Number 466 | rawah
# Processing Record Number 467 | tuatapere
# Processing Record Number 468 | marawi
# Processing Record Number 469 | chesma
# Processing Record Number 470 | beyneu
# Processing Record Number 471 | jiddah
# City not found. Skipping...
# Processing Record Number 472 | college
# Processing Record Number 473 | portland
# Processing Record Number 474 | gzhatsk
# City not found. Skipping...
# Processing Record Number 475 | mount gambier
# Processing Record Number 476 | le vauclin
# Processing Record Number 477 | georgiyevka
# Processing Record Number 478 | caorle
# Processing Record Number 479 | novyy urengoy
# Processing Record Number 480 | copiapo
# Processing Record Number 481 | paramonga
# Processing Record Number 482 | kulhudhuffushi
# Processing Record Number 483 | lugovoy
# Processing Record Number 484 | babanusah
# City not found. Skipping...
# Processing Record Number 485 | cairns
# Processing Record Number 486 | oranjemund
# Processing Record Number 487 | vangaindrano
# Processing Record Number 488 | egersund
# Processing Record Number 489 | burnie
# Processing Record Number 490 | baraolt
# Processing Record Number 491 | reshetylivka
# Processing Record Number 492 | borujan
# City not found. Skipping...
# Processing Record Number 493 | vardo
# Processing Record Number 494 | vao
# Processing Record Number 495 | one hundred mile house
# City not found. Skipping...
# Processing Record Number 496 | dharan
# Processing Record Number 497 | zhenhai
# Processing Record Number 498 | puerto madryn
# Processing Record Number 499 | high rock
# Processing Record Number 500 | rolla
# Processing Record Number 501 | amderma
# City not found. Skipping...
# Processing Record Number 502 | rovaniemi
# Processing Record Number 503 | moses lake
# Processing Record Number 504 | zwedru
# Processing Record Number 505 | talnakh
# Processing Record Number 506 | finnsnes
# Processing Record Number 507 | pelym
# Processing Record Number 508 | baleshwar
# Processing Record Number 509 | hervey bay
# Processing Record Number 510 | jabiru
# City not found. Skipping...
# Processing Record Number 511 | sorvag
# City not found. Skipping...
# Processing Record Number 512 | santa cecilia
# Processing Record Number 513 | kemlya
# Processing Record Number 514 | jiangyou
# Processing Record Number 515 | cam pha
# City not found. Skipping...
# Processing Record Number 516 | aguimes
# Processing Record Number 517 | patea
# Processing Record Number 518 | pirawa
# Processing Record Number 519 | kangaatsiaq
# Processing Record Number 520 | bend
# Processing Record Number 521 | assai
# Processing Record Number 522 | tibati
# Processing Record Number 523 | olafsvik
# Processing Record Number 524 | kieta
# Processing Record Number 525 | grenfell
# Processing Record Number 526 | kinsale
# Processing Record Number 527 | howard springs
# Processing Record Number 528 | riberalta
# Processing Record Number 529 | caravelas
# Processing Record Number 530 | vrises
# Processing Record Number 531 | shache
# Processing Record Number 532 | havoysund
# Processing Record Number 533 | novochernorechenskiy
# Processing Record Number 534 | ostrovnoy
# Processing Record Number 535 | sinnamary
# Processing Record Number 536 | dinsor
# City not found. Skipping...
# Processing Record Number 537 | catazaja
# Processing Record Number 538 | saint anthony
# Processing Record Number 539 | camabatela
# Processing Record Number 540 | oistins
# Processing Record Number 541 | tigil
# Processing Record Number 542 | berbera
# Processing Record Number 543 | kununurra
# Processing Record Number 544 | fare
# Processing Record Number 545 | ortakoy
# Processing Record Number 546 | flinders
# Processing Record Number 547 | bako
# Processing Record Number 548 | palabuhanratu
# City not found. Skipping...
# Processing Record Number 549 | goianesia
# Processing Record Number 550 | toamasina
# Processing Record Number 551 | kaohsiung
# Processing Record Number 552 | casian
# Processing Record Number 553 | umm lajj
# Processing Record Number 554 | onguday
# Processing Record Number 555 | valparaiso
# Processing Record Number 556 | ucluelet
# Processing Record Number 557 | dubbo
# Processing Record Number 558 | joensuu
# Processing Record Number 559 | saleaula
# City not found. Skipping...
# Processing Record Number 560 | palampur
# Processing Record Number 561 | kawalu
# Processing Record Number 562 | pio xii
# Processing Record Number 563 | pangnirtung
# Processing Record Number 564 | jiazi
# Processing Record Number 565 | asino
# Processing Record Number 566 | sumbawa
# City not found. Skipping...
# Processing Record Number 567 | pochutla
# Processing Record Number 568 | cartagena
# Processing Record Number 569 | bolshegrivskoye
# City not found. Skipping...
# Processing Record Number 570 | sovetskiy
# Processing Record Number 571 | albemarle
# Processing Record Number 572 | tame
# Processing Record Number 573 | turochak
# Processing Record Number 574 | stephenville
# Processing Record Number 575 | chengde
# Processing Record Number 576 | gomel
# Processing Record Number 577 | canto do buriti
# Processing Record Number 578 | oum hadjer
# Processing Record Number 579 | sao jose da coroa grande
# Processing Record Number 580 | manaus
# Processing Record Number 581 | broken hill
# Processing Record Number 582 | kutum
# Processing Record Number 583 | rocky mountain house
# Processing Record Number 584 | paracatu
# Processing Record Number 585 | cheuskiny
# City not found. Skipping...
# Processing Record Number 586 | hamza
# Processing Record Number 587 | gopalpur
# Processing Record Number 588 | sao jose do belmonte
# Processing Record Number 589 | acarau
# Processing Record Number 590 | san policarpo
# Processing Record Number 591 | kavieng
# Processing Record Number 592 | morehead
# Processing Record Number 593 | mazamari
# Processing Record Number 594 | balakhta
# Processing Record Number 595 | quatre cocos
# Processing Record Number 596 | las vegas
# Processing Record Number 597 | tessalit
# Processing Record Number 598 | brae
# Processing Record Number 599 | iqaluit
# Processing Record Number 600 | bonavista
# Processing Record Number 601 | novyy svit
# Processing Record Number 602 | madaripur
# Processing Record Number 603 | krasnoselkup
# Processing Record Number 604 | eureka
# Processing Record Number 605 | kristiansund
# Processing Record Number 606 | lima
# Processing Record Number 607 | anloga
# Processing Record Number 608 | oktyabrskoye
# Processing Record Number 609 | sao joao da barra
# Processing Record Number 610 | amazar
# Processing Record Number 611 | port augusta
# Processing Record Number 612 | la ronge
# Processing Record Number 613 | odesskoye
# Processing Record Number 614 | nachingwea
# Processing Record Number 615 | melfi
# Processing Record Number 616 | nagorsk
# Processing Record Number 617 | lucea
# Processing Record Number 618 | formosa
# Processing Record Number 619 | waipawa
# Processing Record Number 620 | manaure
# Processing Record Number 621 | bosaso
# Processing Record Number 622 | onega
# Processing Record Number 623 | saltillo
# Processing Record Number 624 | mrirt
# City not found. Skipping...
# Processing Record Number 625 | male
# Processing Record Number 626 | malindi
# Processing Record Number 627 | biak
# Processing Record Number 628 | beaverlodge
# Processing Record Number 629 | berlevag
# Processing Record Number 630 | abasolo
# Processing Record Number 631 | blagoyevo
# Processing Record Number 632 | korla
# Processing Record Number 633 | doha
# Processing Record Number 634 | skjervoy
# Processing Record Number 635 | ust-kut
# Processing Record Number 636 | tshikapa
# Processing Record Number 637 | mareeba
# Processing Record Number 638 | strai
# Processing Record Number 639 | el alto
# Processing Record Number 640 | chilca

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(city_dict)

# %%
city_df.set_index('City_Name')
# Out:
#               Lat     Lon  Max_Temp  Humidity  Clouds  Wind_Speed Country  \
# City_Name
# Butaritari   3.07  172.79     83.34        70      62       10.58      KI
# Albany      42.60  -73.97     80.01        82      75        9.91      US
# Dikson      73.51   80.55     42.01        98     100       16.80      RU
# Taoudenni   22.68   -3.98     98.51        34      48       14.23      ML
# Castro     -24.79  -50.01     63.81        73       0        3.89      BR
# ...           ...     ...       ...       ...     ...         ...     ...
# Tshikapa    -6.42   20.80     81.10        57      45        2.93      CD
# Mareeba    -17.00  145.43     70.00        85      97        3.00      AU
# Strai       58.20    7.90     55.99       100       0        4.70      NO
# El Alto     -4.27  -81.21     65.55        75       5       18.79      PE
# Chilca     -12.52  -76.74     62.60        77      90        9.17      PE
#
#                   Date
# City_Name
# Butaritari  1598738087
# Albany      1598738076
# Dikson      1598738095
# Taoudenni   1598738232
# Castro      1598738110
# ...                ...
# Tshikapa    1598738354
# Mareeba     1598738355
# Strai       1598738355
# El Alto     1598738355
# Chilca      1598738230
#
# [586 rows x 8 columns]

# %%
city_df.to_csv('city_data.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# checks to see if there are any cities in the list with more than 100% humidity.

extra_humid = 0

for h in city_df['Humidity']:
    if h > 100:
        extra_humid =+ 1
        
if extra_humid > 0:
    print("You need to do this step!")

else:
    print("You can skip this step!")
# Out:
# You can skip this step!

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
current_date = date.today()

# %%
lat_plot = city_df['Lat']
temp_plot = city_df['Max_Temp']

plt.scatter(lat_plot, temp_plot, edgecolor="k")
plt.title(f'City Latitude vs Maximum Temperature ({current_date})')
plt.ylabel('Max Temp (F)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig("Figures/Lat_vs_Temp.png")

# Analyzing how maximum temperature is affected by the change in latitude

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
humidity_plot = city_df['Humidity']

plt.scatter(lat_plot, humidity_plot, edgecolor="k")
plt.title(f'City Latitude vs Humidity ({current_date})')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig('Figures/Lat_vs_Humidity.png')

# Analyzing how humidity is affected by the change in latitude

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clouds_plot = city_df['Clouds']

plt.scatter(lat_plot, clouds_plot, edgecolor="k")
plt.title(f'City Latitude vs Cloudiness ({current_date})')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig('Figures/Lat_vs_Clouds.png')

# Analyzing how cloudiness is affected by the change in latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
windSpeed_plot = city_df['Wind_Speed']

plt.scatter(lat_plot, clouds_plot, edgecolor="k")
plt.title(f'City Latitude vs Wind Speed ({current_date})')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig('Figures/Lat_vs_WindSpeed.png')

# Analyzing how cloudiness is affected by the change in latitude

# %% [markdown]
# ## Linear Regression

# %%
#Isolating the northern latitudes
lat_north = city_df.loc[city_df['Lat']>=0]
north_df = pd.DataFrame(lat_north)

# %%
#isolating the southern latitudes
lat_south = city_df.loc[city_df['Lat']<0]
south_df = pd.DataFrame(lat_south)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Max_Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.grid(b = True, alpha = .25)
plt.title(f'Northern Hemisphere - Max Temp vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)} indicating a strong negative correlation.')
# Out:
# The linear regression line equation is: y = -0.59x + 91.57.
# The correlation is: -0.77 indicating a strong negative correlation.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Max_Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Max Temp vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)} indicating a strong positive correlation.')
# Out:
# The linear regression line equation is: y = 0.74x + 81.13.
# The correlation is: 0.73 indicating a strong positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.04x + 71.34.
# The correlation is: 0.04, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.18x + 73.45.
# The correlation is: 0.13, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Clouds']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which indicates there is no coorelation.')
# Out:
# The linear regression line equation is: y = -0.01x + 54.38.
# The correlation is: -0.01, which indicates there is no coorelation.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Clouds']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.26x + 46.26.
# The correlation is: 0.09, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Wind_Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.01x + 7.53.
# The correlation is: 0.02, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Wind_Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = -0.09x + 8.0.
# The correlation is: -0.18, which does not indicate a very strong coorelation.
